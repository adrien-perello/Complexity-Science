# %%
# before everything, import these libraries (Shift-Enter)

from IPython.lib.display import YouTubeVideo

# %% [markdown]
# # II. Coding Projects > Chaos Game
#
#
# <hr>
# &nbsp;

# %%
YouTubeVideo('7gNzMtYo9n4',width=560,height=315)

# %%
YouTubeVideo('A0NHGTggoOQ',width=560,height=315)
