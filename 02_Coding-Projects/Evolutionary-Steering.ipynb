# %%
# before everything, import these libraries (Shift-Enter)

from IPython.lib.display import YouTubeVideo

# %% [markdown]
# # II. Coding Projects > Evolutionary Steering Behaviors
#
#
# <hr>
# &nbsp;

# %%
YouTubeVideo('flxOkx0yLrY',width=560,height=315)

# %%
YouTubeVideo('XaOVH8ZSRNA',width=560,height=315)

# %%
YouTubeVideo('vZUWTlK7D2Q',width=560,height=315)

# %%
YouTubeVideo('ykOcaInciBI',width=560,height=315)

# %%
YouTubeVideo('VnFF5V5DS8s',width=560,height=315)
