# %%
# before everything, import these libraries (Shift-Enter)

from IPython.lib.display import YouTubeVideo

# %% [markdown]
# # II. Coding Projects > Predator-Prey (Lotka Volterra)
#
# <hr>
# &nbsp;
#
# Check the [Complexity explorable article](https://www.complexity-explorables.org/explorables/lotka-martini/)

# %%
YouTubeVideo('M0nRWcF1WJw',width=560,height=315)
