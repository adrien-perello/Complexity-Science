# %%
# before everything, import these libraries (Shift-Enter)

from IPython.lib.display import YouTubeVideo

# %% [markdown]
# # II. Coding Projects > Daisyworld
#
#
# <hr>
# &nbsp;

# %%
YouTubeVideo('sCxIqgZA7ag',width=560,height=315)

# %%
YouTubeVideo('inVZoI1AkC8',width=560,height=315)

# %% [markdown]
# Check following notebooks:
# - [mrernst](https://github.com/mrernst/daisyworld)
# - [darren1998s](https://github.com/darren1998s/Daisyworld)
