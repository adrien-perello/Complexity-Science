# %%
# before everything, import these libraries (Shift-Enter)

from IPython.lib.display import YouTubeVideo

# %% [markdown]
# # II. Coding Projects > Flocking Simulation
#
#
# <hr>
# &nbsp;
#
# Check the following interactive articles:
# - [Flocking Simulation](https://www.complexity-explorables.org/explorables/flockn-roll/)
# - [Swarming behavior with Schelling model](https://www.complexity-explorables.org/explorables/thrilling-milling-schelling-herings/)

# %%
YouTubeVideo('mhjuuHl6qHM',width=560,height=315)

# %%
YouTubeVideo('bqtqltqcQhw',width=560,height=315)
