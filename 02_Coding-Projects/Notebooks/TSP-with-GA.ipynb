# %%
# before everything, import these libraries (Shift-Enter)

from IPython.lib.display import YouTubeVideo

# %% [markdown]
# # II. Coding Projects > Traveling Salesperson with Genetic Algorithm]
#
#
# <hr>
# &nbsp;

# %%
YouTubeVideo('M3KTWnTrU_c',width=560,height=315)

# %%
YouTubeVideo('hnxn6DtLYcY',width=560,height=315)
